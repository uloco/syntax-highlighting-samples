# %%
# Variables, types, strings
name: str = "Jupyter"
count: int = 42
ratio: float = 3.14
active: bool = True
items: list[int] = [1, 2, 3]
mapping: dict[str, int] = {"a": 1, "b": 2}

f_string = f"Hello {name}, count is {count * 2}"
raw = r"No \escape"
multi = """line one
line two"""

# %%
# Functions, decorators, classes
from functools import wraps
from dataclasses import dataclass
from abc import ABC, abstractmethod

def log(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        print(f"Calling {func.__name__}")
        return func(*args, **kwargs)
    return wrapper

@log
def add(a: int, b: int = 0) -> int:
    """Add two numbers."""
    return a + b

square = lambda x: x ** 2

class Shape(ABC):
    @abstractmethod
    def area(self) -> float: ...

@dataclass
class Circle(Shape):
    radius: float
    def area(self) -> float:
        from math import pi
        return pi * self.radius ** 2

# %%
# Control flow, exceptions, comprehensions
for i in range(5):
    if i % 2 == 0:
        print(i)
    else:
        continue

match "start":
    case "start": print("go")
    case _: print("unknown")

try:
    result = int("nope")
except ValueError as e:
    print(f"Error: {e}")
finally:
    print("done")

squares = [x ** 2 for x in range(10) if x % 2 == 0]
word_len = {w: len(w) for w in ["hello", "world"]}

# %%
# Async, generators, context managers
import asyncio
from contextlib import contextmanager

async def fetch(url: str) -> dict:
    await asyncio.sleep(0.1)
    return {"url": url}

def fibonacci(limit: int):
    a, b = 0, 1
    while a < limit:
        yield a
        a, b = b, a + b

@contextmanager
def timer(label: str):
    import time
    start = time.perf_counter()
    try:
        yield
    finally:
        print(f"{label}: {time.perf_counter() - start:.4f}s")

# %%
# Magic commands
# %timeit sum(range(1000))
# !echo "shell escape"

# %% [raw]
# This is a raw cell. Not executed, not rendered as markdown.

# %%
print("stdout output")
# Out:
# stdout output

# %%
# Data output
{"result": 42, "items": [1, 2, 3]}
# Out:
# {'result': 42, 'items': [1, 2, 3]}

# %%
# Error output
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ZeroDivisionError: division by zero
